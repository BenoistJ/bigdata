# %%
rdd = sc.textFile("hdfs:///user/root/datafr.csv")
rdd.take(10).foreach(println)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-22-171365c256b5> in <module>()
#       1 rdd = sc.textFile("hdfs:///user/root/datafr.csv")
# ----> 2 rdd.take(10).foreach(println)
#
# /opt/cloudera/parcels/CDH-5.10.1-1.cdh5.10.1.p0.10/lib/spark/python/pyspark/rdd.pyc in take(self, num)
#    1265         """
#    1266         items = []
# -> 1267         totalParts = self.getNumPartitions()
#    1268         partsScanned = 0
#    1269
#
# /opt/cloudera/parcels/CDH-5.10.1-1.cdh5.10.1.p0.10/lib/spark/python/pyspark/rdd.pyc in getNumPartitions(self)
#     354         2
#     355         """
# --> 356         return self._jrdd.partitions().size()
#     357
#     358     def filter(self, f):
#
# /opt/cloudera/parcels/CDH-5.10.1-1.cdh5.10.1.p0.10/lib/spark/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
# ...
